# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-JersonDavidPerezContreras/blob/main/CursoIBM2/Semana_7_Data_Analysis_with_Python_(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TECNOLOGICO DE MONTEREY
#
#
#
#
#
# #Maestria en inteligencia artificial aplicada
#
#
#
#
#
# ##Ciencia y Analitica de datos
#
#
#
#
#
# ## Profesora:
#
# María de la Paz Rico Fernández
#
#
#
#
#
# # Presentado por:
#
# Jerson David Perez Contreras
#
# A01793810
#
# Liga Git:
# https://github.com/PosgradoMNA/actividades-de-aprendizaje-JersonDavidPerezContreras/blob/main/CursoIBM2/Semana_7_Data_Analysis_with_Python_%28IBM%29.ipynb

# %% [markdown]
# #Labs
#
# Dada las intrucciones de clase, para facilitar las entregas se puede descargar y subir el labs. Se comparte liga del notebook del labs desarrollado y subido al Git:
#
# https://github.com/PosgradoMNA/actividades-de-aprendizaje-JersonDavidPerezContreras/blob/main/CursoIBM2/DA0101EN-4-Review-Model-Development.jupyterlite.ipynb

# %% [markdown]
# #Graded Review Questions
#
# #Question 1
#
# Sea X un marco de datos con 100 filas y 5 columnas. Sea yel objetivo con 100 muestras. Suponiendo que se hayan importado todas las bibliotecas y datos relevantes, se ha ejecutado la siguiente línea de código:
#
# LR = LinearRegression()
#
# LR.fit(X, y)
#
# yhat = LR.predict(X)
#
# ¿Cuántas muestras yhatcontiene?
#
# RTA: 100 Observaciones, ya que optiene la prediccion de y dado las varaibles x
#
#
# #Question 2
#
# ¿Qué valor de R^2 (coeficiente de determinación) indica que su modelo funciona mejor?
#
# RTA= 1 Indica que el 100% de la varible explica el modelo
#
# #Question 3
#
# ¿Qué afirmación es verdadera sobre la regresión lineal polinomial?
#
# RTA= Aunque las variables predictoras de la regresión lineal polinomial no son lineales, la relación entre los parámetros o coeficientes es lineal.
#
# #Question 4
#
# Cuanto mayor sea el error cuadrático medio, mejor funcionará su modelo:
#
# RTA= Falso, el MSE  es la diferencia entre la prediccion  o estimado y el real, a una menor diferencia el modelo funciona mejor
#
# #Question 5
#
# Suponga que se importan todas las bibliotecas. y es el objetivo y X son las características o variables dependientes. Considere las siguientes líneas de código:
#
#     input=[('scale',StandardScaler()),('model',LinearRegression())]
#
#     pipe=Pipeline(Input)
#
#     pipe.fit(X,y)
#
#     ypipe=pipe.predict(X)
#
#
# ¿Cuál es el resultado de ypipe?
#
# RTA: Standardize the data, then perform prediction using a linear regression model., EL Pipeline, nos permite hacer el modelo siguiendo una serie de pasos ordenado, asi en este caso primero se escala, luego de aplica el modelo de regreion lineal.

# %% [markdown]
# # PROGRESO
# ![Progreso Curso 2  IBM 4.png](data:image/png;base64,...)

# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-JersonDavidPerezContreras/blob/main/CursoIBM2/Semana_8_Data_Analysis_with_Python_(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TECNOLOGICO DE MONTEREY
#
#
#
#
#
# #Maestria en inteligencia artificial aplicada
#
#
#
#
#
# ##Ciencia y Analitica de datos
#
#
#
#
#
# ## Profesora:
#
# María de la Paz Rico Fernández
#
#
#
#
#
# # Presentado por:
#
# Jerson David Perez Contreras
#
# A01793810
#
# Liga Git:
#
# https://github.com/PosgradoMNA/actividades-de-aprendizaje-JersonDavidPerezContreras/blob/main/CursoIBM2/Semana_8_Data_Analysis_with_Python_(IBM).ipynb
#
#
# # Labs
#
# Dada las intrucciones de clase, para facilitar las entregas se puede descargar y subir el labs. Se comparte liga del notebook del labs desarrollado y subido al Git:
#
# https://github.com/PosgradoMNA/actividades-de-aprendizaje-JersonDavidPerezContreras/blob/main/CursoIBM2/DA0101EN-5-Review-Model-Evaluation-and-Refinement.jupyterlite.ipynb

# %% [markdown]
# #Graded Review Questions
#
# ##Question 1
#
# in the following plot, the vertical axis shows the mean square error and the horizontal axis represents the order of the polynomial. The red line represents the training error the blue line is the test error. What is the best order of the polynomial given the possible choices in the horizontal axis?
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# RTA: 8: En este polinomio minimiza el error cuadratico medio tanto en los datos de entrenamiento como en los datos de prueba, En polinomios mas bajos los errores son muy altos y en polinomios muy altos, el modelo se sobrentrena generando que en los datos de testeo su error se muy elevado
#
# ## Question 2
#
# What is the correct use of the "train_test_split" function such that 40% of the data samples will be utilized for testing; the parameter "random_state" is set to zero; and the input variables for the features and targets are_data, y_data respectively?
#
# RTA: train_test_split(x_data, y_data, test_size=0.4, random_state=0)
#
# ##Questions 3
#
# What is the output of cross_val_score(lre, x_data, y_data, cv=2)?
#
# RTA: The average R^2 on the test data for each of the two folds.
#
# ##Question 4
#
# What is the code to create a ridge regression object "RR" with an alpha term equal 10?
#
# RTA: RR=Ridge(alpha=10)
#
# ## Question 5
#
#
# What dictionary value would we use to perform a grid search for the following values of alpha: 1,10, 100? No other parameter values should be tested.
#
# RTA: [{'alpha': [1,10,100]}]

# %% [markdown]
# #EXAMEN FINAL
# ##Question 1
#
# What does the following command do?
#
# df.dropna(subset=["price"], axis=0)
#
# RTA: Drop the “not a number” values from the column "price".
#
# ##Question 2
#
# How would you provide many of the summary statistics for all the columns in the dataframe "df"?
#
# rta: df.describe(include = "all")
#
#
# ##Question 3
#
# How would you find the shape of the dataframe df?
#
# RTA: df.shape
#
# ##Question 4
#
# What task does the following command, df.to_csv("A.csv"), perform:
#
# RTA: Save the dataframe df to a csv file called "A.csv".
#
# ##Question 5
#
# What task does the following line of code perform?
#
# result = np.linspace(min(df["city-mpg"]), max(df["city-mpg"]), 5)
#
# RTA=  Builds a bin array ranging from the smallest value to the largest value of "city-mpg" in order to build 4 bins of equal length. (Hay como un eror deberia se 5 secciones)
#
# ##Question 6
# What task does the following line of code perform:
#
# df['peak-rpm'].replace(np.nan, 5,inplace=True)
#
# rta :Replace the "not a number" values with 5 in the column 'peak-rpm'.
#
# ##Question 7
#
# How do you "one-hot encode" the column 'fuel-type' in the dataframe df?
#
# RTA= pd.get_dummies(df["fuel-type"])
#
# ##Question 8
#
# What does the vertical axis on a scatterplot represent?
#
# rta= Dependent variable
#
# ##Question 9
#
# What does the horizontal axis on a scatterplot represent?
#
# RTA= Independent variable
#
# ##Question 10
# If we have 10 columns and 100 samples, how large is the output of df.corr()?
#
# RTA: 10 x10
#
# ## Question 11
#
# What is the largest possible element resulting in the following operation "df.corr()"?
#
# rta: 1
#
# ##Question 12
#
# If the Pearson Correlation of two variables is zero:
#
# RTA = The two variables are not correlated.
#
#
# ##Question 13
#
# If the p-value of the Pearson Correlation is 1:
#
# RTA: None of the above.
#
# ##Question 14
#
# What does the following line of code do: lm = LinearRegression()?
#
#
# RTA: Create a linear regression object.
#
# #Question 15
#
# If the predicted function is:
#
# Yhat = a + b1 X1 + b2 X2 + b3 X3 + b4 X4
#
# The method is:
#
# rta: Multiple Linear Regression
#
# ##Question 16
#
# What steps do the following lines of code perform:
#
# Input=[('scale',StandardScaler()),('model',LinearRegression())]
#
# pipe=Pipeline(Input)
#
# pipe.fit(Z,y)
#
# ypipe=pipe.predict(Z)
#
# RTA: Standardize the data, then perform a prediction using a linear regression model using the features Z and targets y.
#
# ##Question 17
#
# What is the maximum value of R^2 that can be obtained?
#
# rta: 1
#
# ##Question 18
#
# We create a polynomial feature PolynomialFeatures(degree=2). What is the order of the polynomial?
#
# RTA= 2
#
# ##Question 19
#
# You have a linear model. The average R^2 value on your training data is 0.5. You perform a 100th order polynomial transform on your data, then use these values to train another model. Your average R^2 is 0.99. Which comment is correct?
#
# rta= The results on your training data is not the best indicator of how your model performs. You should use your test data to get a beter idea.
#
# ##Question 20
#
# You train a ridge regression model. You get a R^2 of 1 on your validation data and you get a R^2 of 0.5 on your training data. What should you do?
#
# RTA= Nothing. Your model performs flawlessly on your validation data.

# %% [markdown]
# # progreso
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Badge
#
# ![image.png](data:image/png;base64,...)
